# %% [markdown]
# <a href="https://colab.research.google.com/github/JarmoIoT/JarmoIoT/blob/master/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#
# Python coding task
# Create this and add it to github
#

import datetime
import json
import zipfile
from google.colab import drive
drive.mount('/content/drive')
import os

# Add necessary imports here

#functions
def destroyfile(filename):

    if os.path.exists(filename):
        os.remove(filename)
        print(filename + "destroyed")
    else:
        print(filename + "does not exist")



# Step 1: Get sentence to be handled
sentence = input("Enter your sentence")
print(sentence)

# Step 2: Create a timestamp

timestamp = str (datetime.datetime.now(datetime.timezone.utc))

print (timestamp)

# Step 3: Add sentence and time stamp to object

myobject = { 
    "mysentence" : sentence,
    "mytimestamp" : timestamp
}

print (myobject)

# Step 4: convert object to JSON 

jsonobject = json.dumps(myobject)

print (jsonobject)

# Step 5: save json object as myfile.json

f= open ("myfile.json", "w")

f.write(jsonobject)
f.close()

# Step 6: compress file to zip

archive = zipfile.ZipFile ('Archive.zip', mode='w')
try:
    archive.write('myfile.json')
    print('Files added to zipfile')

finally:
    print('Reading files now')
    archive.close

    

# --- and now vice versa!


if os.path.exists("myfile.json"):
    os.remove("myfile.json")
    print("myfile.json destroyed!")
else:
    print("myfile.json does not exist")

#Step 7: Destroy json file and hen unzip it from zipfile, then desroy zip file


destroyfile("myfile.json")

unarchive = zipfile.ZipFile ("Archive.zip", "r")

try:
    unarchive.extractall()
    print('Files extracted from archive')

finally:
    unarchive.close()
    print('Files extraction finished')

destroyfile("Archive.zip")
    
# 8: read json object

fout = open ("myfile.json", "r")

jsonobjectout = fout.read()
fout.close()
print (jsonobjectout)

destroyfile("myfile.json")

# Step 9 change json to object

myobjectout = json.loads(jsonobjectout)
print (myobjectout)

#10: Print object

print(myobjectout["mysentence"])
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter your sentencemhhggjgkgjggjkg
# mhhggjgkgjggjkg
# 2019-12-19 10:45:21.106321+00:00
# {'mysentence': 'mhhggjgkgjggjkg', 'mytimestamp': '2019-12-19 10:45:21.106321+00:00'}
# {"mysentence": "mhhggjgkgjggjkg", "mytimestamp": "2019-12-19 10:45:21.106321+00:00"}
# Files added to zipfile
# Reading files now
# myfile.json destroyed!
# myfile.jsondoes not exist
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-23-7793939ea316> in <module>()
#      79 destroyfile("myfile.json")
#      80
# ---> 81 unarchive = zipfile.ZipFile ("Archive.zip", "r")
#      82
#      83 try:
#
# /usr/lib/python3.6/zipfile.py in __init__(self, file, mode, compression, allowZip64)
#    1129         try:
#    1130             if mode == 'r':
# -> 1131                 self._RealGetContents()
#    1132             elif mode in ('w', 'x'):
#    1133                 # set the modified flag so central directory gets written
#
# /usr/lib/python3.6/zipfile.py in _RealGetContents(self)
#    1224             centdir = struct.unpack(structCentralDir, centdir)
#    1225             if centdir[_CD_SIGNATURE] != stringCentralDir:
# -> 1226                 raise BadZipFile("Bad magic number for central directory")
#    1227             if self.debug > 2:
#    1228                 print(centdir)
#
# BadZipFile: Bad magic number for central directory
